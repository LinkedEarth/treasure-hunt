# %% [markdown]
# # LMR Seasonal Temperature Analysis
#
# This notebook analyzes temperature reconstruction data from the LMR Seasonal dataset.

# %%
import pyleoclim as pyleo
import pandas as pd
import re

# %% [markdown]
# ## 1. Load CSV as Pyleoclim GeoSeries
#
# Extract lat/lon from the filename and create a GeoSeries object.

# %%
# Filename and pattern to extract lat/lon
filename = 'ts_lmr_v2_1_0_tas_annual_lat_30.0_lon_-90.0.csv'

# Extract latitude and longitude from filename
lat_match = re.search(r'lat_([\-\d.]+)_', filename)
lon_match = re.search(r'lon_([\-\d.]+)\.csv', filename)

lat = float(lat_match.group(1))
lon = float(lon_match.group(1))

print(f"Latitude: {lat}°N, Longitude: {lon}°E")
# Out:
# Latitude: 30.0°N, Longitude: -90.0°E

# %%
df = pd.read_csv(filename, skiprows=12)
df
# Out:
#       Year (CE)  LMR mean (degrees Celsius)
# 0           0.0                        0.08
# 1           1.0                        0.15
# 2           2.0                        0.07
# 3           3.0                        0.07
# 4           4.0                        0.12
# ...         ...                         ...
# 1996     1996.0                        0.37
# 1997     1997.0                        0.35
# 1998     1998.0                        0.33
# 1999     1999.0                        0.55
# 2000     2000.0                        0.52
#
# [2001 rows x 2 columns]

# %% [markdown]
# Create a GeoSeries object:

# %%
gs = pyleo.GeoSeries(
    time=df.iloc[:,0].values,
    value=df.iloc[:,1].values,
    lat=lat,
    lon=lon,
    time_name='Year',
    time_unit='CE',
    value_name='Temperature',
    value_unit='°C',
    label='LMR v2.1 mean'
)

print(gs)
# Out:
# Time axis values sorted in ascending order
# {'label': 'LMR v2.1 mean'}
# None
# Time [years CE]
# 0.0       0.08
# 1.0       0.15
# 2.0       0.07
# 3.0       0.07
# 4.0       0.12
#           ...
# 1996.0    0.37
# 1997.0    0.35
# 1998.0    0.33
# 1999.0    0.55
# 2000.0    0.52
# Name: Temperature [°C], Length: 2001, dtype: float64

# %% [markdown]
# ## 2. Dashboard Visualization
#
# Use the dashboard() feature to create an interactive overview.

# %%
gs.dashboard()
# Out:
# ['missing']
# Using serial execution for this method on a Mac platform
# Performing spectral analysis on individual series: 100%|██████████| 200/200 [00:24<00:00,  8.03it/s]
# (<Figure size 1100x800 with 4 Axes>,
#  {'ts': <Axes: xlabel='Time [years CE]', ylabel='Temperature [°C]'>,
#   'dts': <Axes: xlabel='Counts'>,
#   'map': {'map': <GeoAxes: xlabel='lon', ylabel='lat'>},
#   'spec': <Axes: xlabel='Period [years]', ylabel='PSD'>})

# %% [markdown]
# ## 3. Warming Stripes Visualization
#
# Create a warming stripes visualization.

# %%
gs.stripes()
# Out:
# (<Figure size 800x100 with 1 Axes>, <Axes: >)

# %% [markdown]
# ## 4. MTM Spectral Analysis
#
# Apply Multi-Taper Method (MTM) spectral analysis with significance testing.

# %%
# Perform MTM spectral analysis
psd = gs.spectral(method='mtm')

# Run significance test with default parameters
psd_signif = psd.signif_test(number=500)

# Plot the results
psd_signif.plot()
# Out:
# Performing spectral analysis on individual series: 100%|██████████| 500/500 [00:05<00:00, 99.07it/s]
# (<Figure size 1000x400 with 1 Axes>,
#  <Axes: xlabel='Period [years]', ylabel='PSD'>)
