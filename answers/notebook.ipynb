# %%
import pandas as pd

# Read CSV file, skipping the first 12 lines and using comma as separator
# quotechar handles the quotes around each row
df = pd.read_csv('https://paleopresto.com/images/lmr/ts_lmr_v2_0_0_tas_annual_lat_30.0_lon_-90.0.csv', skiprows=12, sep=',', quotechar='"')

# Display the first few rows
df.head()
# Out:
#    Year (CE)  LMR mean (degrees Celsius)
# 0        0.0                       -0.14
# 1        1.0                        0.04
# 2        2.0                       -0.01
# 3        3.0                       -0.04
# 4        4.0                        0.03

# %%
import pyleoclim as pyleo

ts = pyleo.Series(time=df.iloc[:,0], value=df.iloc[:,1])
fig,ax = ts.stripes()
# Out:
# Time axis values sorted in ascending order

# %%
ax
# Out:
# <Axes: >
